# %%
from exobrain_entity_recognizer.recognizer import EntityRecognizer

# %%
recognizer = EntityRecognizer('en')

# %%
s = 'spaCy features an extremely fast statistical entity recognition system, Clinton that assigns labels to contiguous spans of tokens. The default model identifies a variety of named and numeric entities, including companies, locations, organizations and products. You can add arbitrary classes to the entity recognition system, and update the model with new examples.'

recognizer(s)
# Out:
# [{'id': 0,
#   'text': 'clinton',
#   'lemma': 'clinton',
#   'left_contexts': ['spacy',
#    'features',
#    'an',
#    'extremely',
#    'fast',
#    'statistical',
#    'entity',
#    'recognition',
#    'system',
#    ','],
#   'right_contexts': ['that',
#    'assigns',
#    'labels',
#    'to',
#    'contiguous',
#    'spans',
#    'of',
#    'tokens',
#    '.'],
#   'label': 'PERSON'},
#  {'id': 1,
#   'text': 'an extremely fast statistical entity recognition system',
#   'lemma': 'an extremely fast statistical entity recognition system',
#   'left_contexts': ['spacy', 'features'],
#   'right_contexts': [',',
#    'clinton',
#    'that',
#    'assigns',
#    'labels',
#    'to',
#    'contiguous',
#    'spans',
#    'of',
#    'tokens',
#    '.'],
#   'label': 'NP'},
#  {'id': 2,
#   'text': 'labels',
#   'lemma': 'label',
#   'left_contexts': ['spacy',
#    'features',
#    'an',
#    'extremely',
#    'fast',
#    'statistical',
#    'entity',
#    'recognition',
# ...

# %%
recognizer(s)
# Out:
# [{'id': 0,
#   'text': 'clinton',
#   'lemma': 'clinton',
#   'left_contexts': ['spacy',
#    'features',
#    'an',
#    'extremely',
#    'fast',
#    'statistical',
#    'entity',
#    'recognition',
#    'system',
#    ','],
#   'right_contexts': ['that',
#    'assigns',
#    'labels',
#    'to',
#    'contiguous',
#    'spans',
#    'of',
#    'tokens',
#    '.'],
#   'label': 'PERSON'},
#  {'id': 1,
#   'text': 'an extremely fast statistical entity recognition system',
#   'lemma': 'an extremely fast statistical entity recognition system',
#   'left_contexts': ['spacy', 'features'],
#   'right_contexts': [',',
#    'clinton',
#    'that',
#    'assigns',
#    'labels',
#    'to',
#    'contiguous',
#    'spans',
#    'of',
#    'tokens',
#    '.'],
#   'label': 'NP'},
#  {'id': 2,
#   'text': 'labels',
#   'lemma': 'label',
#   'left_contexts': ['spacy',
#    'features',
#    'an',
#    'extremely',
#    'fast',
#    'statistical',
#    'entity',
#    'recognition',
# ...

# %%
recognizer.save_dict('./test.json')
